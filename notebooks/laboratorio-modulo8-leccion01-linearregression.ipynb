# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import numpy as np
import pandas as pd

# Otros objetivos
# -----------------------------------------------------------------------
import math

# Gráficos
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model

import sys
sys.path.append("../")
# import funciones as spc

# %%
df = pd.read_csv("../data/autorenew_clean_estandar_sin_out_enc.csv", index_col=0)

# %%
df.head()
# Out:
#                              name        seller     offerType        abtest  \
# 0                      Golf_3_1.6  10690.276627  10690.427773  10881.719377
# 1            A5_Sportback_2.7_Tdi  10690.276627  10690.427773  10881.719377
# 2  Jeep_Grand_Cherokee_"Overland"  10690.276627  10690.427773  10881.719377
# 3              GOLF_4_1_4__3TÜRER  10690.276627  10690.427773  10881.719377
# 4  Skoda_Fabia_1.4_TDI_PD_Classic  10690.276627  10690.427773  10881.719377
#
#     vehicleType       gearbox         model      fuelType         brand  \
# 0  11782.788729   7912.576455  19432.719222   8753.180097  14478.707539
# 1  24522.523514   7912.576455  22216.943078  10392.232891  12732.911834
# 2  13006.873725  13095.469467   9876.840722  10392.232891  11828.021066
# 3   5558.219446   7912.576455  19432.719222   8753.180097  14478.707539
# 4   5558.219446   7912.576455   4127.675481  10392.232891   6310.378124
#
#    notRepairedDamage          dateCreated             lastSeen  price_knn  \
# 0       20760.717591  2016-03-24 00:00:00  2016-04-07 03:16:57     2990.0
# 1        6147.926747  2016-03-24 00:00:00  2016-04-07 01:46:50    18300.0
# 2       20760.717591  2016-03-14 00:00:00  2016-04-05 12:47:46     9800.0
# 3        8559.115090  2016-03-17 00:00:00  2016-03-17 17:40:17     1500.0
# 4        8559.115090  2016-03-31 00:00:00  2016-04-06 10:17:21     3600.0
#
#    monthOfRegistration_knn  postalCode_knn  powerCV_estandar  \
# 0                      6.0         49733.0         -0.052593
# 1                      5.0         66954.0          0.385348
# 2                      8.0         90480.0          0.248162
# 3                      6.0         91074.0         -0.210886
# 4                      7.0         60437.0         -0.242544
#
#    kilometer_estandar  yearOfRegistration_estandar
# 0            0.607813                    -0.016995
# 1           -0.015437                     0.069147
# 2           -0.015437                    -0.006227
# 3            0.607813                    -0.038530
# 4           -0.887987                     0.036844

# %%
lista_cols = df.columns.unique().to_list()

# %%
lista_cols.remove('name')
lista_cols.remove('lastSeen')
lista_cols.remove('dateCreated')

# %%
df_temp = df[lista_cols]
df_temp.head()
# Out:
#          seller     offerType        abtest   vehicleType       gearbox  \
# 0  10690.276627  10690.427773  10881.719377  11782.788729   7912.576455
# 1  10690.276627  10690.427773  10881.719377  24522.523514   7912.576455
# 2  10690.276627  10690.427773  10881.719377  13006.873725  13095.469467
# 3  10690.276627  10690.427773  10881.719377   5558.219446   7912.576455
# 4  10690.276627  10690.427773  10881.719377   5558.219446   7912.576455
#
#           model      fuelType         brand  notRepairedDamage  price_knn  \
# 0  19432.719222   8753.180097  14478.707539       20760.717591     2990.0
# 1  22216.943078  10392.232891  12732.911834        6147.926747    18300.0
# 2   9876.840722  10392.232891  11828.021066       20760.717591     9800.0
# 3  19432.719222   8753.180097  14478.707539        8559.115090     1500.0
# 4   4127.675481  10392.232891   6310.378124        8559.115090     3600.0
#
#    monthOfRegistration_knn  postalCode_knn  powerCV_estandar  \
# 0                      6.0         49733.0         -0.052593
# 1                      5.0         66954.0          0.385348
# 2                      8.0         90480.0          0.248162
# 3                      6.0         91074.0         -0.210886
# 4                      7.0         60437.0         -0.242544
#
#    kilometer_estandar  yearOfRegistration_estandar
# 0            0.607813                    -0.016995
# 1           -0.015437                     0.069147
# 2           -0.015437                    -0.006227
# 3            0.607813                    -0.038530
# 4           -0.887987                     0.036844

# %%
list_x = df_temp.columns
list(list_x).remove('price_knn')

df_x = df_temp[list_x]

df_y = pd.DataFrame(df['price_knn']).reset_index(drop=True)

# %%
df_x.head()
# Out:
#          seller     offerType        abtest   vehicleType       gearbox  \
# 0  10690.276627  10690.427773  10881.719377  11782.788729   7912.576455
# 1  10690.276627  10690.427773  10881.719377  24522.523514   7912.576455
# 2  10690.276627  10690.427773  10881.719377  13006.873725  13095.469467
# 3  10690.276627  10690.427773  10881.719377   5558.219446   7912.576455
# 4  10690.276627  10690.427773  10881.719377   5558.219446   7912.576455
#
#           model      fuelType         brand  notRepairedDamage  price_knn  \
# 0  19432.719222   8753.180097  14478.707539       20760.717591     2990.0
# 1  22216.943078  10392.232891  12732.911834        6147.926747    18300.0
# 2   9876.840722  10392.232891  11828.021066       20760.717591     9800.0
# 3  19432.719222   8753.180097  14478.707539        8559.115090     1500.0
# 4   4127.675481  10392.232891   6310.378124        8559.115090     3600.0
#
#    monthOfRegistration_knn  postalCode_knn  powerCV_estandar  \
# 0                      6.0         49733.0         -0.052593
# 1                      5.0         66954.0          0.385348
# 2                      8.0         90480.0          0.248162
# 3                      6.0         91074.0         -0.210886
# 4                      7.0         60437.0         -0.242544
#
#    kilometer_estandar  yearOfRegistration_estandar
# 0            0.607813                    -0.016995
# 1           -0.015437                     0.069147
# 2           -0.015437                    -0.006227
# 3            0.607813                    -0.038530
# 4           -0.887987                     0.036844

# %%
df_y.head()
# Out:
#    price_knn
# 0     2990.0
# 1    18300.0
# 2     9800.0
# 3     1500.0
# 4     3600.0

# %%
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y, train_size=0.7, random_state=42)

# %%
regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
datos = regr.predict(x_test)
print(datos)
# Out:
# [[2950.]
#  [ 500.]
#  [5699.]
#  ...
#  [2499.]
#  [4700.]
#  [9890.]]
